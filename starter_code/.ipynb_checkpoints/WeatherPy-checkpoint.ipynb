# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID="
target_url = url + weather_api_key
target_url
# Out:
# 'http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID=c50ed6501b7a41f66d34d7f8a05f54b7'

# %%
# Checking my connection
weather_response = requests.get(target_url)
weather_json = weather_response.json()
print(json.dumps(weather_json, indent=4, sort_keys=True))
# Out:
# {
#     "city": {
#         "coord": {
#             "lat": 55.7522,
#             "lon": 37.6156
#         },
#         "country": "RU",
#         "id": 524901,
#         "name": "Moscow",
#         "sunrise": 1591231814,
#         "sunset": 1591293953,
#         "timezone": 10800
#     },
#     "cnt": 40,
#     "cod": "200",
#     "list": [
#         {
#             "clouds": {
#                 "all": 35
#             },
#             "dt": 1591293600,
#             "dt_txt": "2020-06-04 18:00:00",
#             "main": {
#                 "feels_like": 286.1,
#                 "grnd_level": 988,
#                 "humidity": 70,
#                 "pressure": 1004,
#                 "sea_level": 1004,
#                 "temp": 288.97,
#                 "temp_kf": 0.16,
#                 "temp_max": 288.97,
#                 "temp_min": 288.81
#             },
#             "rain": {
#                 "3h": 0.13
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 188,
#                 "speed": 4.3
#             }
#         },
#         {
#             "clouds": {
#                 "all": 30
#             },
#             "dt": 1591304400,
#             "dt_txt": "2020-06-04 21:00:00",
#             "main": {
#                 "feels_like": 283.8,
#                 "grnd_level": 990,
#                 "humidity": 78,
#                 "pressure": 1006,
#                 "sea_level": 1006,
#                 "temp": 287,
#                 "temp_kf": 0.59,
#                 "temp_max": 287,
#                 "temp_min": 286.41
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 214,
#                 "speed": 4.66
#             }
#         },
#         {
#             "clouds": {
#                 "all": 17
#             },
#             "dt": 1591315200,
#             "dt_txt": "2020-06-05 00:00:00",
#             "main": {
#                 "feels_like": 282.77,
#                 "grnd_level": 992,
#                 "humidity": 85,
#                 "pressure": 1008,
#                 "sea_level": 1008,
#                 "temp": 285.15,
#                 "temp_kf": 0.27,
#                 "temp_max": 285.15,
#                 "temp_min": 284.88
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 193,
#                 "speed": 3.29
#             }
#         },
#         {
#             "clouds": {
#                 "all": 1
#             },
#             "dt": 1591326000,
#             "dt_txt": "2020-06-05 03:00:00",
#             "main": {
#                 "feels_like": 282.2,
#                 "grnd_level": 992,
#                 "humidity": 82,
#                 "pressure": 1008,
#                 "sea_level": 1008,
#                 "temp": 285.22,
#                 "temp_kf": 0.03,
#                 "temp_max": 285.22,
#                 "temp_min": 285.19
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 167,
#                 "speed": 4.04
#             }
#         },
#         {
#             "clouds": {
#                 "all": 24
#             },
#             "dt": 1591336800,
#             "dt_txt": "2020-06-05 06:00:00",
#             "main": {
#                 "feels_like": 286.02,
#                 "grnd_level": 993,
#                 "humidity": 66,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "temp": 289.48,
#                 "temp_kf": 0,
#                 "temp_max": 289.48,
#                 "temp_min": 289.48
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 168,
#                 "speed": 4.99
#             }
#         },
#         {
#             "clouds": {
#                 "all": 45
#             },
#             "dt": 1591347600,
#             "dt_txt": "2020-06-05 09:00:00",
#             "main": {
#                 "feels_like": 287.85,
#                 "grnd_level": 993,
#                 "humidity": 51,
#                 "pressure": 1008,
#                 "sea_level": 1008,
#                 "temp": 292.66,
#                 "temp_kf": 0,
#                 "temp_max": 292.66,
#                 "temp_min": 292.66
#             },
#             "rain": {
#                 "3h": 1.21
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 176,
#                 "speed": 6.59
#             }
#         },
#         {
#             "clouds": {
#                 "all": 72
#             },
#             "dt": 1591358400,
#             "dt_txt": "2020-06-05 12:00:00",
#             "main": {
#                 "feels_like": 287.38,
#                 "grnd_level": 993,
#                 "humidity": 57,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "temp": 292.02,
#                 "temp_kf": 0,
#                 "temp_max": 292.02,
#                 "temp_min": 292.02
#             },
#             "rain": {
#                 "3h": 2.46
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 181,
#                 "speed": 6.75
#             }
#         },
#         {
#             "clouds": {
#                 "all": 98
#             },
#             "dt": 1591369200,
#             "dt_txt": "2020-06-05 15:00:00",
#             "main": {
#                 "feels_like": 283.12,
#                 "grnd_level": 993,
#                 "humidity": 81,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "temp": 287.04,
#                 "temp_kf": 0,
#                 "temp_max": 287.04,
#                 "temp_min": 287.04
#             },
#             "rain": {
#                 "3h": 6.84
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "moderate rain",
#                     "icon": "10d",
#                     "id": 501,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 192,
#                 "speed": 5.93
#             }
#         },
#         {
#             "clouds": {
#                 "all": 88
#             },
#             "dt": 1591380000,
#             "dt_txt": "2020-06-05 18:00:00",
#             "main": {
#                 "feels_like": 283.57,
#                 "grnd_level": 993,
#                 "humidity": 80,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "temp": 286.18,
#                 "temp_kf": 0,
#                 "temp_max": 286.18,
#                 "temp_min": 286.18
#             },
#             "rain": {
#                 "3h": 1.2
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 153,
#                 "speed": 3.66
#             }
#         },
#         {
#             "clouds": {
#                 "all": 46
#             },
#             "dt": 1591390800,
#             "dt_txt": "2020-06-05 21:00:00",
#             "main": {
#                 "feels_like": 283.28,
#                 "grnd_level": 994,
#                 "humidity": 90,
#                 "pressure": 1010,
#                 "sea_level": 1010,
#                 "temp": 285.28,
#                 "temp_kf": 0,
#                 "temp_max": 285.28,
#                 "temp_min": 285.28
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 178,
#                 "speed": 3.13
#             }
#         },
#         {
#             "clouds": {
#                 "all": 65
#             },
#             "dt": 1591401600,
#             "dt_txt": "2020-06-06 00:00:00",
#             "main": {
#                 "feels_like": 283.68,
#                 "grnd_level": 995,
#                 "humidity": 93,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "temp": 284.84,
#                 "temp_kf": 0,
#                 "temp_max": 284.84,
#                 "temp_min": 284.84
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 178,
#                 "speed": 1.95
#             }
#         },
#         {
#             "clouds": {
#                 "all": 39
#             },
#             "dt": 1591412400,
#             "dt_txt": "2020-06-06 03:00:00",
#             "main": {
#                 "feels_like": 284.18,
#                 "grnd_level": 995,
#                 "humidity": 90,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "temp": 285.36,
#                 "temp_kf": 0,
#                 "temp_max": 285.36,
#                 "temp_min": 285.36
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 173,
#                 "speed": 1.99
#             }
#         },
#         {
#             "clouds": {
#                 "all": 33
#             },
#             "dt": 1591423200,
#             "dt_txt": "2020-06-06 06:00:00",
#             "main": {
#                 "feels_like": 288.55,
#                 "grnd_level": 996,
#                 "humidity": 73,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "temp": 290.07,
#                 "temp_kf": 0,
#                 "temp_max": 290.07,
#                 "temp_min": 290.07
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 164,
#                 "speed": 3.07
#             }
#         },
#         {
#             "clouds": {
#                 "all": 4
#             },
#             "dt": 1591434000,
#             "dt_txt": "2020-06-06 09:00:00",
#             "main": {
#                 "feels_like": 291.3,
#                 "grnd_level": 997,
#                 "humidity": 64,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "temp": 293.57,
#                 "temp_kf": 0,
#                 "temp_max": 293.57,
#                 "temp_min": 293.57
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 177,
#                 "speed": 4.75
#             }
#         },
#         {
#             "clouds": {
#                 "all": 22
#             },
#             "dt": 1591444800,
#             "dt_txt": "2020-06-06 12:00:00",
#             "main": {
#                 "feels_like": 292.47,
#                 "grnd_level": 997,
#                 "humidity": 65,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "temp": 294.24,
#                 "temp_kf": 0,
#                 "temp_max": 294.24,
#                 "temp_min": 294.24
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 183,
#                 "speed": 4.45
#             }
#         },
#         {
#             "clouds": {
#                 "all": 60
#             },
#             "dt": 1591455600,
#             "dt_txt": "2020-06-06 15:00:00",
#             "main": {
#                 "feels_like": 294.93,
#                 "grnd_level": 996,
#                 "humidity": 61,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "temp": 296.32,
#                 "temp_kf": 0,
#                 "temp_max": 296.32,
#                 "temp_min": 296.32
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 196,
#                 "speed": 4.41
#             }
#         },
#         {
#             "clouds": {
#                 "all": 80
#             },
#             "dt": 1591466400,
#             "dt_txt": "2020-06-06 18:00:00",
#             "main": {
#                 "feels_like": 293.04,
#                 "grnd_level": 997,
#                 "humidity": 74,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "temp": 293.36,
#                 "temp_kf": 0,
#                 "temp_max": 293.36,
#                 "temp_min": 293.36
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 190,
#                 "speed": 2.98
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1591477200,
#             "dt_txt": "2020-06-06 21:00:00",
#             "main": {
#                 "feels_like": 291.7,
#                 "grnd_level": 998,
#                 "humidity": 82,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "temp": 291.86,
#                 "temp_kf": 0,
#                 "temp_max": 291.86,
#                 "temp_min": 291.86
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 208,
#                 "speed": 2.83
#             }
#         },
#         {
#             "clouds": {
#                 "all": 97
#             },
#             "dt": 1591488000,
#             "dt_txt": "2020-06-07 00:00:00",
#             "main": {
#                 "feels_like": 290.75,
#                 "grnd_level": 1000,
#                 "humidity": 88,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "temp": 290.55,
#                 "temp_kf": 0,
#                 "temp_max": 290.55,
#                 "temp_min": 290.55
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 232,
#                 "speed": 2.23
#             }
#         },
#         {
#             "clouds": {
#                 "all": 25
#             },
#             "dt": 1591498800,
#             "dt_txt": "2020-06-07 03:00:00",
#             "main": {
#                 "feels_like": 291.1,
#                 "grnd_level": 1001,
#                 "humidity": 84,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "temp": 290.82,
#                 "temp_kf": 0,
#                 "temp_max": 290.82,
#                 "temp_min": 290.82
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 249,
#                 "speed": 1.87
#             }
#         },
#         {
#             "clouds": {
#                 "all": 29
#             },
#             "dt": 1591509600,
#             "dt_txt": "2020-06-07 06:00:00",
#             "main": {
#                 "feels_like": 296.22,
#                 "grnd_level": 1002,
#                 "humidity": 63,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 295.41,
#                 "temp_kf": 0,
#                 "temp_max": 295.41,
#                 "temp_min": 295.41
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 249,
#                 "speed": 1.09
#             }
#         },
#         {
#             "clouds": {
#                 "all": 53
#             },
#             "dt": 1591520400,
#             "dt_txt": "2020-06-07 09:00:00",
#             "main": {
#                 "feels_like": 300.08,
#                 "grnd_level": 1003,
#                 "humidity": 49,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 299.53,
#                 "temp_kf": 0,
#                 "temp_max": 299.53,
#                 "temp_min": 299.53
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 216,
#                 "speed": 1.42
#             }
#         },
#         {
#             "clouds": {
#                 "all": 28
#             },
#             "dt": 1591531200,
#             "dt_txt": "2020-06-07 12:00:00",
#             "main": {
#                 "feels_like": 301,
#                 "grnd_level": 1003,
#                 "humidity": 42,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 301.25,
#                 "temp_kf": 0,
#                 "temp_max": 301.25,
#                 "temp_min": 301.25
#             },
#             "rain": {
#                 "3h": 0.16
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 208,
#                 "speed": 2.15
#             }
#         },
#         {
#             "clouds": {
#                 "all": 45
#             },
#             "dt": 1591542000,
#             "dt_txt": "2020-06-07 15:00:00",
#             "main": {
#                 "feels_like": 300.98,
#                 "grnd_level": 1002,
#                 "humidity": 50,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 299.61,
#                 "temp_kf": 0,
#                 "temp_max": 299.61,
#                 "temp_min": 299.61
#             },
#             "rain": {
#                 "3h": 0.18
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 319,
#                 "speed": 0.44
#             }
#         },
#         {
#             "clouds": {
#                 "all": 49
#             },
#             "dt": 1591552800,
#             "dt_txt": "2020-06-07 18:00:00",
#             "main": {
#                 "feels_like": 297.3,
#                 "grnd_level": 1003,
#                 "humidity": 66,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 296.17,
#                 "temp_kf": 0,
#                 "temp_max": 296.17,
#                 "temp_min": 296.17
#             },
#             "rain": {
#                 "3h": 0.9
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 119,
#                 "speed": 1.4
#             }
#         },
#         {
#             "clouds": {
#                 "all": 68
#             },
#             "dt": 1591563600,
#             "dt_txt": "2020-06-07 21:00:00",
#             "main": {
#                 "feels_like": 295.31,
#                 "grnd_level": 1003,
#                 "humidity": 76,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 294.03,
#                 "temp_kf": 0,
#                 "temp_max": 294.03,
#                 "temp_min": 294.03
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 189,
#                 "speed": 1.28
#             }
#         },
#         {
#             "clouds": {
#                 "all": 68
#             },
#             "dt": 1591574400,
#             "dt_txt": "2020-06-08 00:00:00",
#             "main": {
#                 "feels_like": 293.26,
#                 "grnd_level": 1003,
#                 "humidity": 80,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 292.46,
#                 "temp_kf": 0,
#                 "temp_max": 292.46,
#                 "temp_min": 292.46
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 230,
#                 "speed": 1.57
#             }
#         },
#         {
#             "clouds": {
#                 "all": 53
#             },
#             "dt": 1591585200,
#             "dt_txt": "2020-06-08 03:00:00",
#             "main": {
#                 "feels_like": 293.85,
#                 "grnd_level": 1004,
#                 "humidity": 78,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 292.83,
#                 "temp_kf": 0,
#                 "temp_max": 292.83,
#                 "temp_min": 292.83
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 242,
#                 "speed": 1.24
#             }
#         },
#         {
#             "clouds": {
#                 "all": 56
#             },
#             "dt": 1591596000,
#             "dt_txt": "2020-06-08 06:00:00",
#             "main": {
#                 "feels_like": 298.43,
#                 "grnd_level": 1004,
#                 "humidity": 58,
#                 "pressure": 1020,
#                 "sea_level": 1020,
#                 "temp": 297.4,
#                 "temp_kf": 0,
#                 "temp_max": 297.4,
#                 "temp_min": 297.4
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 265,
#                 "speed": 1.07
#             }
#         },
#         {
#             "clouds": {
#                 "all": 9
#             },
#             "dt": 1591606800,
#             "dt_txt": "2020-06-08 09:00:00",
#             "main": {
#                 "feels_like": 301.51,
#                 "grnd_level": 1004,
#                 "humidity": 41,
#                 "pressure": 1020,
#                 "sea_level": 1020,
#                 "temp": 301.37,
#                 "temp_kf": 0,
#                 "temp_max": 301.37,
#                 "temp_min": 301.37
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 245,
#                 "speed": 1.46
#             }
#         },
#         {
#             "clouds": {
#                 "all": 5
#             },
#             "dt": 1591617600,
#             "dt_txt": "2020-06-08 12:00:00",
#             "main": {
#                 "feels_like": 302.26,
#                 "grnd_level": 1003,
#                 "humidity": 38,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 302.71,
#                 "temp_kf": 0,
#                 "temp_max": 302.71,
#                 "temp_min": 302.71
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 205,
#                 "speed": 2.31
#             }
#         },
#         {
#             "clouds": {
#                 "all": 43
#             },
#             "dt": 1591628400,
#             "dt_txt": "2020-06-08 15:00:00",
#             "main": {
#                 "feels_like": 300.22,
#                 "grnd_level": 1003,
#                 "humidity": 51,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 300.2,
#                 "temp_kf": 0,
#                 "temp_max": 300.2,
#                 "temp_min": 300.2
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 272,
#                 "speed": 2.83
#             }
#         },
#         {
#             "clouds": {
#                 "all": 33
#             },
#             "dt": 1591639200,
#             "dt_txt": "2020-06-08 18:00:00",
#             "main": {
#                 "feels_like": 298.67,
#                 "grnd_level": 1003,
#                 "humidity": 58,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 297.68,
#                 "temp_kf": 0,
#                 "temp_max": 297.68,
#                 "temp_min": 297.68
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 289,
#                 "speed": 1.27
#             }
#         },
#         {
#             "clouds": {
#                 "all": 1
#             },
#             "dt": 1591650000,
#             "dt_txt": "2020-06-08 21:00:00",
#             "main": {
#                 "feels_like": 296.6,
#                 "grnd_level": 1003,
#                 "humidity": 67,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 295.35,
#                 "temp_kf": 0,
#                 "temp_max": 295.35,
#                 "temp_min": 295.35
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 342,
#                 "speed": 0.93
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1591660800,
#             "dt_txt": "2020-06-09 00:00:00",
#             "main": {
#                 "feels_like": 294.47,
#                 "grnd_level": 1004,
#                 "humidity": 73,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 293.66,
#                 "temp_kf": 0,
#                 "temp_max": 293.66,
#                 "temp_min": 293.66
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 304,
#                 "speed": 1.41
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1591671600,
#             "dt_txt": "2020-06-09 03:00:00",
#             "main": {
#                 "feels_like": 295.26,
#                 "grnd_level": 1004,
#                 "humidity": 70,
#                 "pressure": 1020,
#                 "sea_level": 1020,
#                 "temp": 294.3,
#                 "temp_kf": 0,
#                 "temp_max": 294.3,
#                 "temp_min": 294.3
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 318,
#                 "speed": 1.17
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1591682400,
#             "dt_txt": "2020-06-09 06:00:00",
#             "main": {
#                 "feels_like": 300.13,
#                 "grnd_level": 1004,
#                 "humidity": 55,
#                 "pressure": 1020,
#                 "sea_level": 1020,
#                 "temp": 298.84,
#                 "temp_kf": 0,
#                 "temp_max": 298.84,
#                 "temp_min": 298.84
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 349,
#                 "speed": 0.97
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1591693200,
#             "dt_txt": "2020-06-09 09:00:00",
#             "main": {
#                 "feels_like": 302.99,
#                 "grnd_level": 1004,
#                 "humidity": 42,
#                 "pressure": 1020,
#                 "sea_level": 1020,
#                 "temp": 302.5,
#                 "temp_kf": 0,
#                 "temp_max": 302.5,
#                 "temp_min": 302.5
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 342,
#                 "speed": 1.65
#             }
#         },
#         {
#             "clouds": {
#                 "all": 15
#             },
#             "dt": 1591704000,
#             "dt_txt": "2020-06-09 12:00:00",
#             "main": {
#                 "feels_like": 302.58,
#                 "grnd_level": 1003,
#                 "humidity": 40,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 302.87,
#                 "temp_kf": 0,
#                 "temp_max": 302.87,
#                 "temp_min": 302.87
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 11,
#                 "speed": 2.54
#             }
#         },
#         {
#             "clouds": {
#                 "all": 88
#             },
#             "dt": 1591714800,
#             "dt_txt": "2020-06-09 15:00:00",
#             "main": {
#                 "feels_like": 300.96,
#                 "grnd_level": 1003,
#                 "humidity": 52,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 300.86,
#                 "temp_kf": 0,
#                 "temp_max": 300.86,
#                 "temp_min": 300.86
#             },
#             "rain": {
#                 "3h": 0.25
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 70,
#                 "speed": 3.23
#             }
#         }
#     ],
#     "message": 0
# }

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# set up lists to hold reponse info
cityname = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
count = 0

#  response = requests.get(query_url + city).json()
    
# Loop through the list of cities and perform a request for data on each
for city in cities:
    weather_response = requests.get(target_url + "&q=" + city + "&units=Imperial")
    weather_json = weather_response.json()
    try:
        cityname.append(weather_json['city']['name'])
        cloudiness.append(weather_json['list'][0]['clouds']['all'])
        country.append(weather_json['city']['country'])
        date.append(weather_json['list'][0]['dt'])
        humidity.append(weather_json['list'][0]['main']['humidity'])
        lat.append(weather_json['city']['coord']['lat'])
        lng.append(weather_json['city']['coord']['lon'])
        max_temp.append(weather_json['list'][0]['main']['temp_max'])
        wind_speed.append(weather_json['list'][0]['wind']['speed'])
        count = count + 1
        print(f"Processing record {count} of Set 1 | {city}")
    except:
        print("Record not found") 
        pass
        
print("Completed")
# Out:
# Processing record 1 of Set 1 | haines junction
# Processing record 2 of Set 1 | egvekinot
# Processing record 3 of Set 1 | mataura
# Processing record 4 of Set 1 | casper
# Processing record 5 of Set 1 | new norfolk
# Processing record 6 of Set 1 | bluff
# Processing record 7 of Set 1 | hobart
# Processing record 8 of Set 1 | santa isabel do rio negro
# Processing record 9 of Set 1 | emba
# Processing record 10 of Set 1 | thompson
# Processing record 11 of Set 1 | black diamond
# Processing record 12 of Set 1 | cape town
# Processing record 13 of Set 1 | hirara
# Processing record 14 of Set 1 | punta arenas
# Processing record 15 of Set 1 | ushuaia
# Processing record 16 of Set 1 | isangel
# Processing record 17 of Set 1 | sobolevo
# Processing record 18 of Set 1 | rikitea
# Record not found
# Processing record 19 of Set 1 | price
# Processing record 20 of Set 1 | kruisfontein
# Processing record 21 of Set 1 | grand haven
# Processing record 22 of Set 1 | atambua
# Processing record 23 of Set 1 | butaritari
# Processing record 24 of Set 1 | shakawe
# Record not found
# Processing record 25 of Set 1 | mahebourg
# Processing record 26 of Set 1 | kapaa
# Processing record 27 of Set 1 | laguna de perlas
# Record not found
# Processing record 28 of Set 1 | avarua
# Processing record 29 of Set 1 | inirida
# Processing record 30 of Set 1 | toora-khem
# Processing record 31 of Set 1 | the valley
# Processing record 32 of Set 1 | vila franca do campo
# Processing record 33 of Set 1 | busselton
# Record not found
# Processing record 34 of Set 1 | hilo
# Processing record 35 of Set 1 | khatanga
# Processing record 36 of Set 1 | saskylakh
# Record not found
# Processing record 37 of Set 1 | provideniya
# Processing record 38 of Set 1 | nuuk
# Processing record 39 of Set 1 | pevek
# Processing record 40 of Set 1 | puerto leguizamo
# Processing record 41 of Set 1 | japura
# Record not found
# Processing record 42 of Set 1 | atuona
# Processing record 43 of Set 1 | yarada
# Processing record 44 of Set 1 | ribeira grande
# Processing record 45 of Set 1 | tiksi
# Processing record 46 of Set 1 | santa fe
# Record not found
# Processing record 47 of Set 1 | krasnyy
# Processing record 48 of Set 1 | smithers
# Processing record 49 of Set 1 | nikolskoye
# Processing record 50 of Set 1 | beringovskiy
# Processing record 51 of Set 1 | vaini
# Record not found
# Processing record 52 of Set 1 | uong bi
# Processing record 53 of Set 1 | yellowknife
# Processing record 54 of Set 1 | morwell
# Processing record 55 of Set 1 | antalaha
# Processing record 56 of Set 1 | alim
# Processing record 57 of Set 1 | jamestown
# Processing record 58 of Set 1 | touros
# Processing record 59 of Set 1 | sandpoint
# Processing record 60 of Set 1 | pangody
# Record not found
# Processing record 61 of Set 1 | jacmel
# Processing record 62 of Set 1 | zhangye
# Record not found
# Record not found
# Processing record 63 of Set 1 | kavieng
# Processing record 64 of Set 1 | pacific grove
# Record not found
# Processing record 65 of Set 1 | mar del plata
# Processing record 66 of Set 1 | vila velha
# Processing record 67 of Set 1 | nouadhibou
# Processing record 68 of Set 1 | gyoda
# Processing record 69 of Set 1 | luderitz
# Processing record 70 of Set 1 | dabhol
# Processing record 71 of Set 1 | port alfred
# Processing record 72 of Set 1 | talnakh
# Processing record 73 of Set 1 | syriam
# Processing record 74 of Set 1 | auki
# Processing record 75 of Set 1 | madimba
# Processing record 76 of Set 1 | kunming
# Processing record 77 of Set 1 | ponta delgada
# Processing record 78 of Set 1 | kangaatsiaq
# Processing record 79 of Set 1 | cap-aux-meules
# Processing record 80 of Set 1 | qaanaaq
# Processing record 81 of Set 1 | mporokoso
# Processing record 82 of Set 1 | faya
# Processing record 83 of Set 1 | dikson
# Processing record 84 of Set 1 | vanimo
# Processing record 85 of Set 1 | hithadhoo
# Processing record 86 of Set 1 | lensk
# Processing record 87 of Set 1 | champasak
# Processing record 88 of Set 1 | salalah
# Processing record 89 of Set 1 | bengkulu
# Processing record 90 of Set 1 | vestmannaeyjar
# Processing record 91 of Set 1 | albany
# Processing record 92 of Set 1 | chokurdakh
# Processing record 93 of Set 1 | lagoa
# Processing record 94 of Set 1 | sitka
# Processing record 95 of Set 1 | korla
# Record not found
# Processing record 96 of Set 1 | helong
# Processing record 97 of Set 1 | nemuro
# Processing record 98 of Set 1 | zemio
# Processing record 99 of Set 1 | yongan
# Processing record 100 of Set 1 | russell
# Processing record 101 of Set 1 | ucluelet
# Processing record 102 of Set 1 | barrow
# Processing record 103 of Set 1 | batagay
# Processing record 104 of Set 1 | saint-philippe
# Processing record 105 of Set 1 | bredasdorp
# Record not found
# Record not found
# Processing record 106 of Set 1 | arlit
# Processing record 107 of Set 1 | victoria
# Processing record 108 of Set 1 | karratha
# Processing record 109 of Set 1 | chernyshevskiy
# Processing record 110 of Set 1 | tuktoyaktuk
# Processing record 111 of Set 1 | batouri
# Processing record 112 of Set 1 | bambous virieux
# Processing record 113 of Set 1 | aklavik
# Processing record 114 of Set 1 | komsomolskiy
# Processing record 115 of Set 1 | diamantino
# Processing record 116 of Set 1 | svarstad
# Processing record 117 of Set 1 | georgetown
# Processing record 118 of Set 1 | port elizabeth
# Processing record 119 of Set 1 | pitimbu
# Processing record 120 of Set 1 | port hardy
# Processing record 121 of Set 1 | tazovskiy
# Processing record 122 of Set 1 | camargo
# Processing record 123 of Set 1 | port lincoln
# Processing record 124 of Set 1 | naze
# Processing record 125 of Set 1 | simao
# Processing record 126 of Set 1 | buluang
# Processing record 127 of Set 1 | dunedin
# Processing record 128 of Set 1 | hof
# Processing record 129 of Set 1 | taltal
# Processing record 130 of Set 1 | townsville
# Processing record 131 of Set 1 | kodiak
# Processing record 132 of Set 1 | paciran
# Processing record 133 of Set 1 | kiama
# Processing record 134 of Set 1 | yatou
# Processing record 135 of Set 1 | muros
# Processing record 136 of Set 1 | katangli
# Processing record 137 of Set 1 | valparaiso
# Processing record 138 of Set 1 | ziro
# Processing record 139 of Set 1 | lorengau
# Processing record 140 of Set 1 | baruun-urt
# Processing record 141 of Set 1 | puerto ayora
# Record not found
# Processing record 142 of Set 1 | arraial do cabo
# Processing record 143 of Set 1 | tasiilaq
# Record not found
# Processing record 144 of Set 1 | turukhansk
# Processing record 145 of Set 1 | itarema
# Processing record 146 of Set 1 | bonavista
# Processing record 147 of Set 1 | bend
# Processing record 148 of Set 1 | lompoc
# Processing record 149 of Set 1 | tatawin
# Processing record 150 of Set 1 | gamba
# Processing record 151 of Set 1 | raton
# Processing record 152 of Set 1 | kutulik
# Processing record 153 of Set 1 | tupaciguara
# Processing record 154 of Set 1 | tautira
# Processing record 155 of Set 1 | ngunguru
# Processing record 156 of Set 1 | opuwo
# Processing record 157 of Set 1 | stralsund
# Processing record 158 of Set 1 | tuatapere
# Processing record 159 of Set 1 | ilulissat
# Processing record 160 of Set 1 | hobe sound
# Processing record 161 of Set 1 | zhangjiakou
# Processing record 162 of Set 1 | kirakira
# Processing record 163 of Set 1 | bathsheba
# Processing record 164 of Set 1 | fortuna
# Processing record 165 of Set 1 | laguna
# Processing record 166 of Set 1 | mahon
# Processing record 167 of Set 1 | adeje
# Processing record 168 of Set 1 | fukue
# Processing record 169 of Set 1 | ulagan
# Processing record 170 of Set 1 | neuquen
# Processing record 171 of Set 1 | cabo san lucas
# Processing record 172 of Set 1 | thinadhoo
# Processing record 173 of Set 1 | marzuq
# Processing record 174 of Set 1 | hermanus
# Processing record 175 of Set 1 | praia
# Processing record 176 of Set 1 | souillac
# Processing record 177 of Set 1 | mandalgovi
# Processing record 178 of Set 1 | esperance
# Processing record 179 of Set 1 | karlskoga
# Processing record 180 of Set 1 | coahuayana
# Record not found
# Processing record 181 of Set 1 | airai
# Processing record 182 of Set 1 | manado
# Processing record 183 of Set 1 | santa maria
# Processing record 184 of Set 1 | champerico
# Record not found
# Processing record 185 of Set 1 | saint-joseph
# Processing record 186 of Set 1 | upernavik
# Processing record 187 of Set 1 | kamaishi
# Processing record 188 of Set 1 | damnagar
# Processing record 189 of Set 1 | ancud
# Processing record 190 of Set 1 | manoel urbano
# Processing record 191 of Set 1 | high rock
# Processing record 192 of Set 1 | vieques
# Processing record 193 of Set 1 | norwich
# Processing record 194 of Set 1 | snezhnogorsk
# Processing record 195 of Set 1 | yining
# Processing record 196 of Set 1 | geraldton
# Processing record 197 of Set 1 | potsdam
# Record not found
# Processing record 198 of Set 1 | ratchaburi
# Processing record 199 of Set 1 | hovd
# Processing record 200 of Set 1 | port macquarie
# Processing record 201 of Set 1 | east london
# Processing record 202 of Set 1 | itapirapua
# Processing record 203 of Set 1 | mackay
# Processing record 204 of Set 1 | torbat-e jam
# Processing record 205 of Set 1 | la baule-escoublac
# Record not found
# Processing record 206 of Set 1 | bethel
# Processing record 207 of Set 1 | castro
# Processing record 208 of Set 1 | adrar
# Processing record 209 of Set 1 | mezen
# Processing record 210 of Set 1 | namibe
# Processing record 211 of Set 1 | fenoarivo
# Processing record 212 of Set 1 | guiratinga
# Processing record 213 of Set 1 | aksu
# Record not found
# Processing record 214 of Set 1 | kaitangata
# Processing record 215 of Set 1 | srednekolymsk
# Processing record 216 of Set 1 | makakilo city
# Processing record 217 of Set 1 | asau
# Processing record 218 of Set 1 | hit
# Processing record 219 of Set 1 | pandan
# Processing record 220 of Set 1 | dasoguz
# Processing record 221 of Set 1 | chateauroux
# Processing record 222 of Set 1 | coihaique
# Record not found
# Processing record 223 of Set 1 | yenotayevka
# Processing record 224 of Set 1 | baculin
# Processing record 225 of Set 1 | omsukchan
# Processing record 226 of Set 1 | ericeira
# Processing record 227 of Set 1 | collie
# Processing record 228 of Set 1 | talara
# Processing record 229 of Set 1 | matara
# Processing record 230 of Set 1 | kitale
# Processing record 231 of Set 1 | calatayud
# Processing record 232 of Set 1 | monchegorsk
# Processing record 233 of Set 1 | narsaq
# Processing record 234 of Set 1 | tangzhai
# Processing record 235 of Set 1 | san jose de las lajas
# Processing record 236 of Set 1 | aasiaat
# Processing record 237 of Set 1 | northam
# Processing record 238 of Set 1 | road town
# Processing record 239 of Set 1 | pontes e lacerda
# Processing record 240 of Set 1 | volot
# Processing record 241 of Set 1 | campo grande
# Record not found
# Processing record 242 of Set 1 | poum
# Processing record 243 of Set 1 | tecoanapa
# Processing record 244 of Set 1 | maumere
# Processing record 245 of Set 1 | trat
# Processing record 246 of Set 1 | dingle
# Processing record 247 of Set 1 | tupik
# Processing record 248 of Set 1 | lewisporte
# Processing record 249 of Set 1 | yankton
# Processing record 250 of Set 1 | slavicin
# Processing record 251 of Set 1 | ocos
# Processing record 252 of Set 1 | garissa
# Record not found
# Processing record 253 of Set 1 | metro
# Processing record 254 of Set 1 | san patricio
# Record not found
# Processing record 255 of Set 1 | sinegorye
# Record not found
# Processing record 256 of Set 1 | zacler
# Processing record 257 of Set 1 | hamilton
# Processing record 258 of Set 1 | sambava
# Processing record 259 of Set 1 | rawah
# Processing record 260 of Set 1 | yakeshi
# Processing record 261 of Set 1 | lebu
# Processing record 262 of Set 1 | yashkul
# Processing record 263 of Set 1 | rongcheng
# Processing record 264 of Set 1 | villaviciosa
# Processing record 265 of Set 1 | mana
# Processing record 266 of Set 1 | merritt island
# Processing record 267 of Set 1 | malabo
# Processing record 268 of Set 1 | roald
# Processing record 269 of Set 1 | faanui
# Processing record 270 of Set 1 | comodoro rivadavia
# Processing record 271 of Set 1 | mubi
# Processing record 272 of Set 1 | southbridge
# Processing record 273 of Set 1 | shemursha
# Processing record 274 of Set 1 | college
# Processing record 275 of Set 1 | harper
# Processing record 276 of Set 1 | qena
# Processing record 277 of Set 1 | sabzevar
# Processing record 278 of Set 1 | paita
# Processing record 279 of Set 1 | longyearbyen
# Processing record 280 of Set 1 | lachhmangarh
# Processing record 281 of Set 1 | naryan-mar
# Processing record 282 of Set 1 | kuusamo
# Processing record 283 of Set 1 | pangnirtung
# Processing record 284 of Set 1 | carnarvon
# Processing record 285 of Set 1 | sangar
# Processing record 286 of Set 1 | marsa matruh
# Processing record 287 of Set 1 | sao francisco de assis
# Processing record 288 of Set 1 | ponta do sol
# Processing record 289 of Set 1 | barhi
# Processing record 290 of Set 1 | puerto escondido
# Processing record 291 of Set 1 | olinda
# Processing record 292 of Set 1 | sao joao da barra
# Processing record 293 of Set 1 | kamloops
# Record not found
# Processing record 294 of Set 1 | sechura
# Processing record 295 of Set 1 | newcastle
# Processing record 296 of Set 1 | bethanien
# Processing record 297 of Set 1 | prundu
# Processing record 298 of Set 1 | lake charles
# Processing record 299 of Set 1 | klaksvik
# Processing record 300 of Set 1 | cangzhou
# Processing record 301 of Set 1 | sao gabriel da cachoeira
# Processing record 302 of Set 1 | omboue
# Processing record 303 of Set 1 | qinnan
# Processing record 304 of Set 1 | saurimo
# Processing record 305 of Set 1 | poso
# Processing record 306 of Set 1 | belaya gora
# Processing record 307 of Set 1 | prince rupert
# Processing record 308 of Set 1 | tambovka
# Processing record 309 of Set 1 | san jose
# Processing record 310 of Set 1 | inhambane
# Record not found
# Processing record 311 of Set 1 | izumo
# Processing record 312 of Set 1 | beipiao
# Processing record 313 of Set 1 | ostrovnoy
# Processing record 314 of Set 1 | meulaboh
# Processing record 315 of Set 1 | kushiro
# Processing record 316 of Set 1 | cidreira
# Processing record 317 of Set 1 | hasaki
# Processing record 318 of Set 1 | peruibe
# Processing record 319 of Set 1 | paamiut
# Processing record 320 of Set 1 | babrala
# Processing record 321 of Set 1 | sioux lookout
# Processing record 322 of Set 1 | yulara
# Processing record 323 of Set 1 | pisco
# Processing record 324 of Set 1 | alofi
# Processing record 325 of Set 1 | buala
# Processing record 326 of Set 1 | melnikovo
# Processing record 327 of Set 1 | maniitsoq
# Processing record 328 of Set 1 | las palmas
# Processing record 329 of Set 1 | vao
# Processing record 330 of Set 1 | praia da vitoria
# Processing record 331 of Set 1 | cabanas
# Processing record 332 of Set 1 | ola
# Processing record 333 of Set 1 | san quintin
# Processing record 334 of Set 1 | caravelas
# Processing record 335 of Set 1 | castrolibero
# Processing record 336 of Set 1 | iwanai
# Processing record 337 of Set 1 | fairview
# Processing record 338 of Set 1 | sao gabriel
# Processing record 339 of Set 1 | grindavik
# Processing record 340 of Set 1 | kununurra
# Processing record 341 of Set 1 | saint george
# Processing record 342 of Set 1 | manokwari
# Processing record 343 of Set 1 | north bend
# Processing record 344 of Set 1 | akyab
# Processing record 345 of Set 1 | belmonte
# Processing record 346 of Set 1 | moose factory
# Record not found
# Processing record 347 of Set 1 | san cristobal
# Processing record 348 of Set 1 | mount gambier
# Processing record 349 of Set 1 | escanaba
# Processing record 350 of Set 1 | pustoshka
# Record not found
# Processing record 351 of Set 1 | dwarka
# Processing record 352 of Set 1 | pemangkat
# Processing record 353 of Set 1 | nabire
# Processing record 354 of Set 1 | lavrentiya
# Processing record 355 of Set 1 | ambon
# Processing record 356 of Set 1 | namanga
# Processing record 357 of Set 1 | acajutla
# Processing record 358 of Set 1 | saint-pierre
# Processing record 359 of Set 1 | cap malheureux
# Processing record 360 of Set 1 | warmbad
# Processing record 361 of Set 1 | akhmim
# Processing record 362 of Set 1 | chara
# Processing record 363 of Set 1 | ranong
# Processing record 364 of Set 1 | jalu
# Processing record 365 of Set 1 | norman wells
# Processing record 366 of Set 1 | ikom
# Processing record 367 of Set 1 | north myrtle beach
# Record not found
# Processing record 368 of Set 1 | morgan city
# Processing record 369 of Set 1 | palasa
# Record not found
# Processing record 370 of Set 1 | redcar
# Processing record 371 of Set 1 | quatre cocos
# Processing record 372 of Set 1 | clyde river
# Processing record 373 of Set 1 | lyuban
# Processing record 374 of Set 1 | bogotol
# Record not found
# Processing record 375 of Set 1 | gat
# Record not found
# Record not found
# Record not found
# Processing record 376 of Set 1 | pyaozerskiy
# Processing record 377 of Set 1 | hofn
# Processing record 378 of Set 1 | camalu
# Processing record 379 of Set 1 | bodden town
# Processing record 380 of Set 1 | amahai
# Record not found
# Processing record 381 of Set 1 | palaia fokaia
# Processing record 382 of Set 1 | vasterhaninge
# Processing record 383 of Set 1 | bakel
# Processing record 384 of Set 1 | ketchikan
# Processing record 385 of Set 1 | necochea
# Processing record 386 of Set 1 | kaoma
# Processing record 387 of Set 1 | cherskiy
# Processing record 388 of Set 1 | salto
# Processing record 389 of Set 1 | kawalu
# Processing record 390 of Set 1 | margate
# Processing record 391 of Set 1 | barentu
# Processing record 392 of Set 1 | codrington
# Processing record 393 of Set 1 | scottsbluff
# Processing record 394 of Set 1 | oranjestad
# Processing record 395 of Set 1 | yenagoa
# Processing record 396 of Set 1 | dakar
# Processing record 397 of Set 1 | pendencias
# Processing record 398 of Set 1 | kostyantynivka
# Processing record 399 of Set 1 | kharitonovo
# Processing record 400 of Set 1 | raudeberg
# Processing record 401 of Set 1 | chingirlau
# Processing record 402 of Set 1 | sarkand
# Processing record 403 of Set 1 | yendi
# Processing record 404 of Set 1 | realeza
# Processing record 405 of Set 1 | berlevag
# Processing record 406 of Set 1 | verkhnevilyuysk
# Processing record 407 of Set 1 | oranjemund
# Processing record 408 of Set 1 | padang
# Processing record 409 of Set 1 | birao
# Processing record 410 of Set 1 | grand gaube
# Processing record 411 of Set 1 | plettenberg bay
# Processing record 412 of Set 1 | ust-nera
# Processing record 413 of Set 1 | odienne
# Processing record 414 of Set 1 | buchanan
# Record not found
# Processing record 415 of Set 1 | leningradskiy
# Processing record 416 of Set 1 | nikki
# Processing record 417 of Set 1 | sumbe
# Processing record 418 of Set 1 | pinheiro
# Processing record 419 of Set 1 | anajatuba
# Processing record 420 of Set 1 | half moon bay
# Processing record 421 of Set 1 | abu zabad
# Processing record 422 of Set 1 | knittelfeld
# Processing record 423 of Set 1 | nyurba
# Processing record 424 of Set 1 | chuy
# Processing record 425 of Set 1 | guerrero negro
# Processing record 426 of Set 1 | nanortalik
# Processing record 427 of Set 1 | ayan
# Processing record 428 of Set 1 | portland
# Processing record 429 of Set 1 | buraydah
# Processing record 430 of Set 1 | gornopravdinsk
# Processing record 431 of Set 1 | santa rosa
# Processing record 432 of Set 1 | nodeland
# Processing record 433 of Set 1 | pemba
# Processing record 434 of Set 1 | marienburg
# Processing record 435 of Set 1 | ardakan
# Processing record 436 of Set 1 | quincy
# Processing record 437 of Set 1 | khilok
# Processing record 438 of Set 1 | rafaela
# Processing record 439 of Set 1 | khingansk
# Processing record 440 of Set 1 | huanren
# Processing record 441 of Set 1 | tual
# Processing record 442 of Set 1 | yeniseysk
# Processing record 443 of Set 1 | kurumkan
# Processing record 444 of Set 1 | torbay
# Processing record 445 of Set 1 | salym
# Processing record 446 of Set 1 | visnes
# Processing record 447 of Set 1 | labuhan
# Processing record 448 of Set 1 | mazagao
# Processing record 449 of Set 1 | baymak
# Processing record 450 of Set 1 | araua
# Processing record 451 of Set 1 | kanel
# Processing record 452 of Set 1 | kuah
# Processing record 453 of Set 1 | san miguel
# Processing record 454 of Set 1 | jibuti
# Processing record 455 of Set 1 | caconda
# Processing record 456 of Set 1 | berdigestyakh
# Processing record 457 of Set 1 | sri aman
# Processing record 458 of Set 1 | severo-kurilsk
# Processing record 459 of Set 1 | lac du bonnet
# Processing record 460 of Set 1 | doha
# Record not found
# Processing record 461 of Set 1 | kloulklubed
# Processing record 462 of Set 1 | cheney
# Processing record 463 of Set 1 | pasni
# Processing record 464 of Set 1 | dondo
# Processing record 465 of Set 1 | cherat
# Processing record 466 of Set 1 | chandbali
# Processing record 467 of Set 1 | moron
# Processing record 468 of Set 1 | los llanos de aridane
# Processing record 469 of Set 1 | florianopolis
# Processing record 470 of Set 1 | kampong thum
# Processing record 471 of Set 1 | sorland
# Processing record 472 of Set 1 | mulege
# Processing record 473 of Set 1 | burns lake
# Processing record 474 of Set 1 | lata
# Processing record 475 of Set 1 | miasskoye
# Processing record 476 of Set 1 | kieta
# Processing record 477 of Set 1 | maler kotla
# Processing record 478 of Set 1 | roma
# Processing record 479 of Set 1 | krasnogvardeyskiy
# Processing record 480 of Set 1 | toktogul
# Processing record 481 of Set 1 | piet retief
# Processing record 482 of Set 1 | westport
# Processing record 483 of Set 1 | waipawa
# Processing record 484 of Set 1 | katsuura
# Processing record 485 of Set 1 | kenai
# Processing record 486 of Set 1 | whyalla
# Processing record 487 of Set 1 | oxilithos
# Processing record 488 of Set 1 | kundiawa
# Record not found
# Processing record 489 of Set 1 | ushtobe
# Processing record 490 of Set 1 | moussoro
# Processing record 491 of Set 1 | voi
# Record not found
# Processing record 492 of Set 1 | manolas
# Processing record 493 of Set 1 | broome
# Processing record 494 of Set 1 | severobaykalsk
# Processing record 495 of Set 1 | saquena
# Processing record 496 of Set 1 | ambilobe
# Processing record 497 of Set 1 | okhotsk
# Processing record 498 of Set 1 | teguise
# Processing record 499 of Set 1 | gwadar
# Processing record 500 of Set 1 | zabaykalsk
# Processing record 501 of Set 1 | parksepa
# Processing record 502 of Set 1 | kouango
# Processing record 503 of Set 1 | jumla
# Processing record 504 of Set 1 | luanda
# Processing record 505 of Set 1 | cockburn town
# Processing record 506 of Set 1 | iquique
# Processing record 507 of Set 1 | vostok
# Processing record 508 of Set 1 | constitucion
# Processing record 509 of Set 1 | nantucket
# Processing record 510 of Set 1 | bassano
# Processing record 511 of Set 1 | solwezi
# Processing record 512 of Set 1 | pulandian
# Processing record 513 of Set 1 | avinurme
# Processing record 514 of Set 1 | tonneins
# Processing record 515 of Set 1 | mawlaik
# Processing record 516 of Set 1 | la ronge
# Record not found
# Processing record 517 of Set 1 | soskovo
# Processing record 518 of Set 1 | krasnomayskiy
# Processing record 519 of Set 1 | tura
# Processing record 520 of Set 1 | hobyo
# Processing record 521 of Set 1 | sao miguel do araguaia
# Processing record 522 of Set 1 | high level
# Processing record 523 of Set 1 | vila do maio
# Processing record 524 of Set 1 | heilbad heiligenstadt
# Processing record 525 of Set 1 | vigia
# Processing record 526 of Set 1 | asosa
# Processing record 527 of Set 1 | tadine
# Processing record 528 of Set 1 | ulan-ude
# Processing record 529 of Set 1 | banda aceh
# Processing record 530 of Set 1 | christchurch
# Processing record 531 of Set 1 | santa cruz
# Processing record 532 of Set 1 | kindu
# Processing record 533 of Set 1 | bilibino
# Processing record 534 of Set 1 | ust-shonosha
# Processing record 535 of Set 1 | olafsvik
# Processing record 536 of Set 1 | yueyang
# Processing record 537 of Set 1 | barmer
# Processing record 538 of Set 1 | buckeye
# Processing record 539 of Set 1 | klyuchi
# Processing record 540 of Set 1 | mountain home
# Processing record 541 of Set 1 | saldanha
# Processing record 542 of Set 1 | acapulco
# Processing record 543 of Set 1 | kayan
# Processing record 544 of Set 1 | stavern
# Processing record 545 of Set 1 | bilma
# Processing record 546 of Set 1 | ilhabela
# Processing record 547 of Set 1 | norrtalje
# Processing record 548 of Set 1 | chapais
# Processing record 549 of Set 1 | enumclaw
# Processing record 550 of Set 1 | suraabad
# Processing record 551 of Set 1 | kibre mengist
# Processing record 552 of Set 1 | rabo de peixe
# Processing record 553 of Set 1 | lebork
# Processing record 554 of Set 1 | mitu
# Processing record 555 of Set 1 | mayo
# Processing record 556 of Set 1 | aksarka
# Processing record 557 of Set 1 | bani
# Processing record 558 of Set 1 | anadyr
# Processing record 559 of Set 1 | bonito
# Processing record 560 of Set 1 | fort nelson
# Processing record 561 of Set 1 | jackson
# Processing record 562 of Set 1 | umm lajj
# Processing record 563 of Set 1 | nekrasovka
# Processing record 564 of Set 1 | balagansk
# Processing record 565 of Set 1 | slobodskoy
# Processing record 566 of Set 1 | kholodnyy
# Processing record 567 of Set 1 | zharkovskiy
# Processing record 568 of Set 1 | saint-georges
# Processing record 569 of Set 1 | jhanjharpur
# Processing record 570 of Set 1 | port blair
# Processing record 571 of Set 1 | baykit
# Processing record 572 of Set 1 | chipata
# Processing record 573 of Set 1 | aquiraz
# Processing record 574 of Set 1 | ouesso
# Processing record 575 of Set 1 | shenjiamen
# Processing record 576 of Set 1 | ialibu
# Processing record 577 of Set 1 | jinchang
# Processing record 578 of Set 1 | sisimiut
# Processing record 579 of Set 1 | soma
# Processing record 580 of Set 1 | lewistown
# I made it through the gauntlet. The message survived!

# %%
# Convert array of JSONs into Pandas DataFrame

weather_dict = {"City": cityname,"Latitude": lat, "Longitude":lng,
                "Max Temp":max_temp,"Humidity":humidity,"Cloudiness":cloudiness,
                "Wind Speed":wind_speed,"Country":country, "Date":date}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#               City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0  Haines Junction   60.7522  -137.5108     51.22        54           0
# 1        Egvekinot   66.3167  -179.1667     44.60        66          30
# 2          Mataura  -46.1927   168.8643     34.77        92          85
# 3           Casper   42.8666  -106.3131     80.67        21          21
# 4      New Norfolk  -42.7826   147.0587     45.43        76          98
#
#    Wind Speed Country        Date
# 0        4.56      CA  1591293600
# 1        1.74      RU  1591293600
# 2        1.97      NZ  1591293600
# 3       23.69      US  1591293600
# 4        3.27      AU  1591293600

# %%
# Export the City_Data into a csv
# weather_data.to_csv(w'output_data\my_weather_data.csv')
# Show Record Count
countform = len(weather_data)
countform
# Out:
# 580

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
scatlat = weather_data["Latitude"]
scattemp = weather_data["Max Temp"]

plt.scatter(scatlat,scattemp)
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('scatplotlatitudemaxtemp')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
scathum = weather_data["Humidity"]

plt.scatter(scatlat,scathum)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('scatplotlatitudehumidity')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
scatcloud = weather_data["Cloudiness"]

plt.scatter(scatlat,scatcloud)
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('scatplotlatitudecloudiness')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
scatwindsp = weather_data["Wind Speed"]

plt.scatter(scatlat,scatwindsp)
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('scatplotlatitudewindspeed')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=14,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northlat_df = weather_data.loc[weather_data["Latitude"] >= 0,:]
southlat_df = weather_data.loc[weather_data["Latitude"] < 0,:]

northlat_df.head()
# Out:
#               City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0  Haines Junction   60.7522  -137.5108     51.22        54           0
# 1        Egvekinot   66.3167  -179.1667     44.60        66          30
# 3           Casper   42.8666  -106.3131     80.67        21          21
# 8             Emba   48.8264    58.1442     72.46        42          83
# 9         Thompson   55.7435   -97.8558     46.06        79          95
#
#    Wind Speed Country        Date
# 0        4.56      CA  1591293600
# 1        1.74      RU  1591293600
# 3       23.69      US  1591293600
# 8       15.19      KZ  1591293600
# 9       12.19      CA  1591293600

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Max Temp"]
plot_linear_regression(x_values,y_values,'Max Temp',(6,30))

plt.savefig('northerntemplat')
# Out:
# The r-squared is: -0.8009969801973303

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Max Temp"]
plot_linear_regression(x_values,y_values,'Max Temp',(6,30))

plt.savefig('southerntemplat')

print("The high r value indicates a strong positive correlation between latitude and max temperature.")
# Out:
# The r-squared is: 0.8275949665441373
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Humidity"]
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig('northernhumlat')
# Out:
# The r-squared is: 0.019327185933841987

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Humidity"]
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig('southernhumlat')

print("The low r values indicate a weak to no relationship between humidity and latitude.")
# Out:
# The r-squared is: -0.011085855717486574
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Cloudiness"]
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig('northerncloudlat')
# Out:
# The r-squared is: -0.019004035180591714

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Cloudiness"]
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig('southerncloudlat')

print("The low r values indicate a weak positive relationship between latitude and cloudiness.")
# Out:
# The r-squared is: 0.10213534927003236
# The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig('northernwindlat')
# Out:
# The r-squared is: -0.01725951441883582

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig('southernwindlat')

print("The low r values indicate that there is no real relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.")
# Out:
# The r-squared is: -0.024333887365850303
# The low r values indicate that there is no real relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.
